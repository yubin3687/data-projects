# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 경고 뜨지 않게 설정
import warnings
warnings.filterwarnings('ignore')

# 그래프 설정
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False

# 데이터 전처리 알고리즘
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# 학습용과 검증용으로 나누는 함수
from sklearn.model_selection import train_test_split

# 교차 검증
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

# 평가함수
# 분류용
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

# 회귀용
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# 모델의 최적의 하이퍼 파라미터를 찾기 위한 도구
from sklearn.model_selection import GridSearchCV

# 머신러닝 알고리즘 - 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier

# 머신러닝 알고리즘 - 회귀
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import VotingRegressor

# 학습 모델 저장을 위한 라이브러리
import pickle

# %% [markdown]
# ### 프로젝트 셋팅

# %%
# 학습이 완료된 모델을 저장할 파일 이름
best_model_path = 'model/best_model_spaceship_titanic.dat'
# 예측 결과를 저장할 파일 이름
prediction_path = 'model/spaceship_titanic_prediction.csv'

# %% [markdown]
# ### 저장한 모델 객체 등을 복원한다.

# %%
with open(best_model_path, 'rb') as fp :
    model1 = pickle.load(fp)
    HomePlanetEndoder = pickle.load(fp)
    CryoSleepEndoder = pickle.load(fp)
    DestinationEndoder = pickle.load(fp)
    VIPEndoder = pickle.load(fp)
    CabinDeckEndoder = pickle.load(fp)
    CabinSideEndoder = pickle.load(fp)
    best_model = pickle.load(fp)
    scalerX = pickle.load(fp)

display(model1)
display(HomePlanetEndoder)
display(CryoSleepEndoder)
display(DestinationEndoder)
display(VIPEndoder)
display(CabinDeckEndoder)
display(CabinSideEndoder)
display(scalerX)
# Out:
# GradientBoostingClassifier(n_estimators=200)
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# StandardScaler()

# %% [markdown]
# ### 예측할 데이터를 준비한다.
# - 모든 준비가 완료되면 입력데이터는 test_X 라는 변수에 담아주도록 한다.

# %%
# 예측할 데이터를 읽어온다.
df1 = pd.read_csv('data/spaceship_test5.csv')
df1
# Out:
#      HomePlanet  CryoSleep    Destination        Age    VIP  RoomService  \
# 0         Earth       True    TRAPPIST-1e  27.000000  False          0.0
# 1         Earth      False    TRAPPIST-1e  19.000000  False          0.0
# 2        Europa       True    55 Cancri e  31.000000  False          0.0
# 3        Europa      False    TRAPPIST-1e  38.000000  False          0.0
# 4         Earth      False    TRAPPIST-1e  20.000000  False         10.0
# ...         ...        ...            ...        ...    ...          ...
# 4272      Earth       True    TRAPPIST-1e  34.000000  False          0.0
# 4273      Earth      False    TRAPPIST-1e  42.000000  False          0.0
# 4274       Mars       True    55 Cancri e  28.771969  False          0.0
# 4275     Europa      False    TRAPPIST-1e  28.771969  False          0.0
# 4276      Earth       True  PSO J318.5-22  43.000000  False          0.0
#
#       FoodCourt  ShoppingMall     Spa  VRDeck  GroupNumber CabinDeck  \
# ...

# %%
# 예측할 데이터 변환
df1['HomePlanet'] = HomePlanetEndoder.transform(df1['HomePlanet'])
df1['CryoSleep'] = CryoSleepEndoder.transform(df1['CryoSleep'])
df1['Destination'] = DestinationEndoder.transform(df1['Destination'])
df1['VIP'] = VIPEndoder.transform(df1['VIP'])
df1['CabinDeck'] = CabinDeckEndoder.transform(df1['CabinDeck'])
df1['CabinSide'] = CabinSideEndoder.transform(df1['CabinSide'])
df1
# Out:
#       HomePlanet  CryoSleep  Destination        Age  VIP  RoomService  \
# 0              0          1            2  27.000000    0          0.0
# 1              0          0            2  19.000000    0          0.0
# 2              1          1            0  31.000000    0          0.0
# 3              1          0            2  38.000000    0          0.0
# 4              0          0            2  20.000000    0         10.0
# ...          ...        ...          ...        ...  ...          ...
# 4272           0          1            2  34.000000    0          0.0
# 4273           0          0            2  42.000000    0          0.0
# 4274           2          1            0  28.771969    0          0.0
# 4275           1          0            2  28.771969    0          0.0
# 4276           0          1            1  43.000000    0          0.0
#
#       FoodCourt  ShoppingMall     Spa  VRDeck  GroupNumber  CabinDeck  \
# ...

# %%
# 데이터 표준화
scaled_data = scalerX.transform(df1)
scaled_data
# Out:
# array([[-0.81725903,  1.36468464,  0.62054498, ...,  0.62642892,
#          0.25899846,  2.01584216],
#        [-0.81725903, -0.73277002,  0.62054498, ...,  0.62642892,
#         -0.84507099,  1.02352181],
#        [ 0.44038529,  1.36468464, -1.83368499, ...,  0.62642892,
#         -0.29303626, -0.9611189 ],
#        ...,
#        [ 1.6980296 ,  1.36468464, -1.83368499, ...,  0.62642892,
#         -0.84507099,  0.03120145],
#        [ 0.44038529, -0.73277002,  0.62054498, ...,  0.62642892,
#         -0.0170189 , -0.9611189 ],
#        [-0.81725903,  1.36468464, -0.60657001, ...,  0.62642892,
#          0.53501582,  1.68506871]])

# %%
# 입력데이터를 test_X 변수에 담아준다.
test_X = scaled_data

# %% [markdown]
# ### 예측하고 저장한다.

# %%
# 예측한다.
y_pred = model1.predict(test_X)
y_pred
# Out:
# array([0., 0., 1., ..., 1., 1., 1.])

# %%
# 결과를 붙힌다음 저장한다.
# 예측할 데이터를 다시 불러온다.
result_df = pd.read_csv('data/spaceship_test.csv')
result_df['Transported'] = y_pred
result_df.to_csv(prediction_path, index=False, encoding='utf-8-sig')
print('저장완료')
# Out:
# 저장완료
