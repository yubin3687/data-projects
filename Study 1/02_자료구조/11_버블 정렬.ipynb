# %% [markdown]
# # 버블 정렬
# - 인접한 값들끼리 비교하여 위치를 교환하는 방식으로 정렬을 수행한다.
# - 교환이 한번도 이루어지지 않았다면 정렬이 완료된 것으로 판단한다
# - 데이터의 상태에 따라서 작업이 금방 끝날 수도 있는 정렬 방식이다.
#
# ![](doc_images/8.png)

# %%
def bubble_sort(data_list) :
    """
        data_list
            정렬할 데이터를 가지고 있는 리스트
    """
    # 반복한다.
    while True :
        # 교환이 이루어졌는지 확인을 위한 변수에 False값을 넣어준다.
        check_change = False
        # 데이터의 수 - 1 만큼 반복한다.
        for idx in range(len(data_list) - 1) :
            # 현재 위치의 변수의 값과 다음 위치의 변수의 값을 비교한다.
            # 만약 다음 위치의 값이 작으면
            if data_list[idx] > data_list[idx + 1] :
                # 두 변수의 값을 교환한다
                data_list[idx], data_list[idx + 1] = data_list[idx + 1], data_list[idx]
                # 교환이 이루어 졌는지 확인을 위한 변수에 True를 넣어준다.
                check_change = True
            print(data_list)
        print("=" * 30)
        # 만약 교환이 이루어지지 않았다면 반복을 중단한다.
        if check_change == False :
            break

# %%
a1 = [10, 2, 7, 4, 1, 5, 8, 6, 3, 9]
bubble_sort(a1)
a1
# Out:
# [2, 10, 7, 4, 1, 5, 8, 6, 3, 9]
# [2, 7, 10, 4, 1, 5, 8, 6, 3, 9]
# [2, 7, 4, 10, 1, 5, 8, 6, 3, 9]
# [2, 7, 4, 1, 10, 5, 8, 6, 3, 9]
# [2, 7, 4, 1, 5, 10, 8, 6, 3, 9]
# [2, 7, 4, 1, 5, 8, 10, 6, 3, 9]
# [2, 7, 4, 1, 5, 8, 6, 10, 3, 9]
# [2, 7, 4, 1, 5, 8, 6, 3, 10, 9]
# [2, 7, 4, 1, 5, 8, 6, 3, 9, 10]
# ...
# [2, 7, 4, 1, 5, 8, 6, 3, 9, 10]
# [2, 4, 7, 1, 5, 8, 6, 3, 9, 10]
# [2, 4, 1, 7, 5, 8, 6, 3, 9, 10]
# [2, 4, 1, 5, 7, 8, 6, 3, 9, 10]
# [2, 4, 1, 5, 7, 8, 6, 3, 9, 10]
# [2, 4, 1, 5, 7, 6, 8, 3, 9, 10]
# [2, 4, 1, 5, 7, 6, 3, 8, 9, 10]
# [2, 4, 1, 5, 7, 6, 3, 8, 9, 10]
# [2, 4, 1, 5, 7, 6, 3, 8, 9, 10]
# ...
# [2, 4, 1, 5, 7, 6, 3, 8, 9, 10]
# [2, 1, 4, 5, 7, 6, 3, 8, 9, 10]
# [2, 1, 4, 5, 7, 6, 3, 8, 9, 10]
# [2, 1, 4, 5, 7, 6, 3, 8, 9, 10]
# [2, 1, 4, 5, 6, 7, 3, 8, 9, 10]
# [2, 1, 4, 5, 6, 3, 7, 8, 9, 10]
# [2, 1, 4, 5, 6, 3, 7, 8, 9, 10]
# [2, 1, 4, 5, 6, 3, 7, 8, 9, 10]
# [2, 1, 4, 5, 6, 3, 7, 8, 9, 10]
# ...
# [1, 2, 4, 5, 6, 3, 7, 8, 9, 10]
# [1, 2, 4, 5, 6, 3, 7, 8, 9, 10]
# ...
