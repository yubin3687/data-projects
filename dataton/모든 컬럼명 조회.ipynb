# %%
import pandas as pd
import os

folder_path = 'C:/Users/USER/Desktop/data/cleaned'  # 7개의 파일이 있는 폴더

# 폴더 내 모든 CSV 파일에 대해 반복
for i, file in enumerate(sorted(os.listdir(folder_path))):
    if file.endswith('.csv'):
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        
        sorted_columns = sorted(df.columns)
        print(f"\n📄 파일 {i+1}: {file}")
        print("알파벳 순 컬럼:")
        print(sorted_columns)
# Out:
# 📄 파일 1: distribution_centers_cleaned.csv
# 알파벳 순 컬럼:
# ['brand', 'category', 'cost', 'department', 'distribution_center_id', 'id', 'name', 'retail_price', 'sku']
#
# 📄 파일 2: events_cleaned.csv
# 알파벳 순 컬럼:
# ['browser', 'city', 'created_at', 'event_type', 'id', 'ip_address', 'postal_code', 'sequence_number', 'session_id', 'state', 'traffic_source', 'uri']
#
# 📄 파일 3: inventory_items_cleaned.csv
# 알파벳 순 컬럼:
# ['cost', 'created_at', 'id', 'product_brand', 'product_category', 'product_department', 'product_distribution_center_id', 'product_id', 'product_name', 'product_retail_price', 'product_sku']
#
# 📄 파일 4: order_items_cleaned.csv
# 알파벳 순 컬럼:
# ['created_at', 'id', 'inventory_item_id', 'order_id', 'product_id', 'sale_price', 'status', 'user_id']
#
# 📄 파일 5: orders_cleaned.csv
# 알파벳 순 컬럼:
# ['created_at', 'gender', 'num_of_item', 'order_id', 'status', 'user_id']
#
# 📄 파일 6: products_cleaned.csv
# 알파벳 순 컬럼:
# ['brand', 'category', 'cost', 'department', 'distribution_center_id', 'id', 'name', 'retail_price', 'sku']
#
# 📄 파일 7: users_cleaned.csv
# 알파벳 순 컬럼:
# ['age', 'city', 'country', 'created_at', 'email', 'first_name', 'gender', 'id', 'last_name', 'latitude', 'longitude', 'postal_code', 'state', 'street_address', 'traffic_source']
